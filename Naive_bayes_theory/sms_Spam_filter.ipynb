# %% [markdown]
# <a href="https://colab.research.google.com/github/karanidenis/Data-projects/blob/main/sms_Spam_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SMS SPAM FILTER MODEL

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import string

# %% [markdown]
# ## Data Loading and Preprocessing

# %%
#read dataset
spam_df = pd.read_csv('/content/drive/MyDrive/Colab-Notebooks/spam.csv', encoding="ISO-8859-1")

print(spam_df[:2])

#subset and rename columns
spam_df = spam_df[['v1', 'v2']]
spam_df.rename(columns={'v1': 'spam', 'v2': 'text'}, inplace=True)

#convert spam column to binary
spam_df.spam = spam_df.spam.apply(lambda s: True if s=='spam' else False)

#lowercase everything and remove punctuation
spam_df.text = spam_df.text.apply(lambda t: t.lower().translate(str.maketrans('', '', string.punctuation)))

#shuffle
spam_df = spam_df.sample(frac=1)
# Out:
#     v1                                                 v2 Unnamed: 2  \
# 0  ham  Go until jurong point, crazy.. Available only ...        NaN
# 1  ham                      Ok lar... Joking wif u oni...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN

# %%
spam_df.head()
# Out:
#        spam                                               text
# 1882  False                      sorry i cant help you on this
# 765    True  ur awarded a city break and could win a å£200 ...
# 4318  False                 are you still playing with gautham
# 851   False  i am real baby i want to bring out your inner ...
# 213   False                                  yup how ì noe leh

# %% [markdown]
# ### Print Spam texts

# %%
for t in spam_df[spam_df.spam == True].iloc[:5].text:
    print(t)
    print('-------')
# Out:
# ur awarded a city break and could win a å£200 summer shopping spree every wk txt store to 88039  skilgme tscs087147403231winawkage16 å£150perwksub
# -------
# themob check out our newest selection of content games tones gossip babes and sport keep your mobile fit and funky text wap to 82468
# -------
# thanks for your ringtone order reference t91 you will be charged gbp 4 per week you can unsubscribe at anytime by calling customer services on 09057039994
# -------
# free game get rayman golf 4 free from the o2 games arcade 1st get ur games settings reply post then save  activ8 press 0 key for arcade termsapply
# -------
# our mobile number has won å£5000 to claim calls us back or ring the claims hot line on 09050005321
# -------

# %% [markdown]
# ### Print Legit statements

# %%
for t in spam_df[spam_df.spam == False].iloc[:5].text:
    print(t)
    print('-------')
# Out:
# sorry i cant help you on this
# -------
# are you still playing with gautham
# -------
# i am real baby i want to bring out your inner tigress
# -------
# yup how ì noe leh
# -------
# princess i like to make love  ltgt  times per night hope thats not a problem
# -------

# %% [markdown]
# ## Create Training and Testing Sets

# %%
#get training set
train_spam_df = spam_df.iloc[:int(len(spam_df)*0.7)] ## 70% for training

#get testing set
test_spam_df = spam_df.iloc[int(len(spam_df)*0.7):]  # 30% for testing

# %%
FRAC_SPAM_TEXTS = train_spam_df.spam.mean()
print(FRAC_SPAM_TEXTS)
# Out:
# 0.13923076923076924

# %% [markdown]
# ## Create Spam Bag of Words and Non-Spam Bag of Words

# %%
#get all words from spam and non-spam datasets
train_spam_words = ' '.join(train_spam_df[train_spam_df.spam == True].text).split(' ')
train_non_spam_words = ' '.join(train_spam_df[train_spam_df.spam == False].text).split(' ')

common_words = set(train_spam_words).intersection(set(train_non_spam_words))
print(common_words)
# Out:
# {'', 'tried', 'and', 'june', 'private', 'get', 'shop', 'cheap', 'every', 'that', 'ends', 'apply', 'space', 'capital', 'code', 'update', 'messages', '3', 'but', 'important', 'lines', 'yahoo', 'days', '3g', 'perfect', 'after', 'password', 'd', 'another', 'credited', 'borin', 'instantly', 'unable', 'there', 'hey', 'lookin', 'simply', 'pounds', 'from', 'congrats', 'did', 'see', 'just', 'message', 'terms', 'box', 'pin', 'pick', 'account', 'mths', 'lots', 'bored', 'faster', 'sub', 'mp3', 's', 'sort', 'send', 'gay', 'people', 'so', 'unlimited', 'energy', 'takes', '4u', 'mini', 'listen', 'nos', 'enter', 'informed', 'free', 'downloaded', 'has', 'answer', '2day', 'ya', 'great', '1000s', 'str', 'number', 'off', 'held', 'in', 'film', 'miss', 'meet', 'secret', 'knows', 'brought', 'unique', 'kick', 'why', 'nights', 'suzy', 'wkend', 'txt', 'being', 'helen', 'benefits', 'started', 'log', 'city', 'b4', 'thinks', 'hi', 'ones', 'here', 'have', 'how', 'in2', 'dates', 'saturday', 'only', 'with', 'pc', 'yours', 'cd', 'keep', 'ok', 'immediately', 'straight', 'still', 'luv', 'suite', 'center', 'minutes', 'round', 'need', 'term', 'recently', 'r', 'james', 'plus', 'per', 'pg', 'reply', 'gossip', 'care', 'driving', 'into', 'approx', 'down', 'cinema', 'loan', 'current', 'camera', 'names', 'website', 'old', 'any', 'wait', 'music', 'fit', 'charge', 'sports', 'about', 'wont', 'cruise', 'thank', 'real', 'use', 'trip', 'waiting', 'been', 'upto', 'top', 'things', 'god', 'would', 'receiving', 'text', 'could', 'issues', 'on', 'are', 'receipt', 'tells', 'direct', 'sport', 'movie', 'follow', '50', 'over', 'chance', 'six', 'reference', 'when', 'texting', 'country', 'glad', 'feb', 'mr', 'play', 'pay', 'getting', 'yr', 'released', 'month', 'goto', 'member', 'strong', 'ill', 'take', 'ice', 'latest', 'hit', 'street', 'support', 'valued', 'called', 'player', 'remove', 'worlds', 'by', 'girls', 'calls', 'airport', 'up', 'this', 'currently', 'settings', 'detroit', 'points', 'beware', 'one', 'vote', 'tom', 'crazy', 'details', 'network', 'p', 'connection', 'package', 'offers', 'lucky', 'heart', 'today', 'phones', 'no', 'touch', 'claire', 'call', '2nd', 'fun', 'time', 'questions', 'enough', 'like', 'him', 'mates', 'enjoy', 'failed', 'wiv', 'game', 'tickets', 'first', 'hard', 'ten', 'tons', 'hide', 'name', 'request', 'pleased', 'each', 'next', 'store', 'chat', 'true', 'ignore', 'content', 'booking', 'sky', 'mind', 'easy', 'ready', 'pound', 'sexy', 'wid', 'dream', 'total', 'missed', 'running', 'alone', '2', 'some', 'local', 'start', 'book', 'naked', 'fancy', 'cheaper', 'selling', 'pub', 'added', 'season', 'key', 'hrs', 'bill', 'fone', 'make', 'now', 'cost', 'to', 'left', 'find', 'med', 'app', 'england', 'xmas', 'january', 'amazing', 'your', 'picked', 'row', 'stop', 'open', 'click', 'darling', 'kept', 'london', 'am', '6months', 'tell', 'fall', 'hockey', 'shows', 'died', 'ben', 'yrs', 'woman', 'night', 'think', 'id', 'king', 'card', 'our', 'warner', 'g', 'lost', 'quote', '6', 'connect', 'week', 'profit', 'rock', 'its', 'which', 'year', 'day', 'cross', 'challenge', 'warm', 'theyre', 'must', 'smart', 'conditions', 'cant', 'they', 'min', 'scotland', 'comes', 'idiot', 'ans', 'lotr', 'line', 'joined', 'question', 'company', 'sn', 'balance', 'visit', 'mystery', 'burns', 'had', 'lonely', 'away', 'go', 'or', 'tour', 'wish', '2morow', 'shopping', 'contract', 're', 'even', 'valentines', 'sat', 'someone', 'weeks', 'due', 'v', 'wat', 'numbers', 'for', 'careful', 'chatting', 'new', 'area', '7', 'pix', 'registered', 'wants', 'whats', 'however', 'arrive', 'selected', 'done', 'service', 'youll', 'karaoke', 'door', 'order', 'talk', 'pass', 'where', 'song', 'town', 'rooms', 'sony', 'july', 'draw', 'going', 'looking', 'starting', 'months', 'access', 'best', 'save', 'walk', 'landline', 'them', 'between', 'previous', 'starts', 'sam', 'either', 'wedding', 'ave', 'contact', 'love', 'news', 'st', 'ending', 'membership', 'fast', 'surprise', 'evening', 'congratulations', 'buy', 'motorola', 'until', 'items ...

# %%
train_spam_bow = dict()
for w in common_words:
    train_spam_bow[w] = train_spam_words.count(w) / len(train_spam_words)

print(train_spam_bow)
# Out:
# {'': 0.012970873786407768, 'tried': 0.0007766990291262136, 'and': 0.007145631067961165, 'june': 7.766990291262136e-05, 'private': 0.0007766990291262136, 'get': 0.004660194174757282, 'shop': 0.00046601941747572817, 'cheap': 0.00023300970873786408, 'every': 0.001941747572815534, 'that': 0.0016310679611650485, 'ends': 0.00023300970873786408, 'apply': 0.0015533980582524273, 'space': 0.0001553398058252427, 'capital': 7.766990291262136e-05, 'code': 0.0014757281553398058, 'update': 0.000854368932038835, 'messages': 0.0007766990291262136, '3': 0.0011650485436893205, 'but': 0.00046601941747572817, 'important': 0.0006990291262135922, 'lines': 7.766990291262136e-05, 'yahoo': 0.0001553398058252427, 'days': 0.0007766990291262136, '3g': 0.0003106796116504854, 'perfect': 7.766990291262136e-05, 'after': 0.0003106796116504854, 'password': 0.0001553398058252427, 'd': 0.0001553398058252427, 'another': 7.766990291262136e-05, 'credited': 7.766990291262136e-05, 'borin': 7.766990291262136e-05, 'instantly': 7.766990291262136e-05, 'unable': 0.0001553398058252427, 'there': 0.0006213592233009709, 'hey': 0.0003106796116504854, 'lookin': 7.766990291262136e-05, 'simply': 0.00023300970873786408, 'pounds': 0.0010097087378640776, 'from': 0.007300970873786408, 'congrats': 0.0006990291262135922, 'did': 7.766990291262136e-05, 'see': 0.0010097087378640776, 'just': 0.00403883495145631, 'message': 0.00170873786407767, 'terms': 0.00046601941747572817, 'box': 0.0013980582524271844, 'pin': 7.766990291262136e-05, 'pick': 7.766990291262136e-05, 'account': 0.0010097087378640776, 'mths': 0.00023300970873786408, 'lots': 7.766990291262136e-05, 'bored': 0.00023300970873786408, 'faster': 7.766990291262136e-05, 'sub': 0.0003883495145631068, 'mp3': 0.0001553398058252427, 's': 0.0006213592233009709, 'sort': 7.766990291262136e-05, 'send': 0.003495145631067961, 'gay': 0.0001553398058252427, 'people': 7.766990291262136e-05, 'so': 0.0013980582524271844, 'unlimited': 0.0006213592233009709, 'energy': 0.0001553398058252427, 'takes': 0.00023300970873786408, '4u': 0.00023300970873786408, 'mini': 7.766990291262136e-05, 'listen': 7.766990291262136e-05, 'nos': 7.766990291262136e-05, 'enter': 0.0006213592233009709, 'informed': 0.0001553398058252427, 'free': 0.011805825242718447, 'downloaded': 7.766990291262136e-05, 'has': 0.00170873786407767, 'answer': 0.0003883495145631068, '2day': 7.766990291262136e-05, 'ya': 7.766990291262136e-05, 'great': 0.0006990291262135922, '1000s': 0.0001553398058252427, 'str': 7.766990291262136e-05, 'number': 0.0018640776699029127, 'off': 0.00023300970873786408, 'held': 7.766990291262136e-05, 'in': 0.004427184466019417, 'film': 0.0001553398058252427, 'miss': 0.00046601941747572817, 'meet': 0.0003106796116504854, 'secret': 0.0005436893203883495, 'knows': 7.766990291262136e-05, 'brought': 7.766990291262136e-05, 'unique': 0.0001553398058252427, 'kick': 0.00023300970873786408, 'why': 0.0005436893203883495, 'nights': 7.766990291262136e-05, 'suzy': 7.766990291262136e-05, 'wkend': 7.766990291262136e-05, 'txt': 0.008466019417475728, 'being': 0.00023300970873786408, 'helen': 7.766990291262136e-05, 'benefits': 7.766990291262136e-05, 'started': 7.766990291262136e-05, 'log': 0.0003106796116504854, 'city': 0.00023300970873786408, 'b4': 0.0003883495145631068, 'thinks': 0.0005436893203883495, 'hi': 0.0007766990291262136, 'ones': 0.0001553398058252427, 'here': 0.0003883495145631068, 'have': 0.007456310679611651, 'how': 0.0005436893203883495, 'in2': 7.766990291262136e-05, 'dates': 7.766990291262136e-05, 'saturday': 0.0003883495145631068, 'only': 0.003883495145631068, 'with': 0.006757281553398059, 'pc': 0.0001553398058252427, 'yours': 0.000854368932038835, 'cd': 0.00046601941747572817, 'keep': 0.0003106796116504854, 'ok': 0.0003106796116504854, 'immediately': 0.0003106796116504854, 'straight': 0.0001553398058252427, 'still': 0.0003883495145631068, 'luv': 0.00023300970873786408, 'suite': 7.766990291262136e-05, 'center': 7.766990291262136e-05, 'minutes': 0.00023300970873786408, 'round ...

# %%
train_non_spam_bow = dict()
for w in common_words:
    train_non_spam_bow[w] = train_non_spam_words.count(w) / len(train_non_spam_words)

print(train_non_spam_bow)
# Out:
# {'': 0.021844457438810458, 'tried': 4.176760504552669e-05, 'and': 0.012718235736362877, 'june': 4.176760504552669e-05, 'private': 2.0883802522763345e-05, 'get': 0.0045317851474396455, 'shop': 0.0001879542227048701, 'cheap': 0.00010441901261381672, 'every': 0.0004594436555007936, 'that': 0.007079609055216774, 'ends': 0.00010441901261381672, 'apply': 2.0883802522763345e-05, 'space': 8.353521009105338e-05, 'capital': 2.0883802522763345e-05, 'code': 2.0883802522763345e-05, 'update': 6.265140756829004e-05, 'messages': 0.00012530281513658008, '3': 0.0006891654832511904, 'but': 0.005951883718987553, 'important': 0.0002297218277503968, 'lines': 2.0883802522763345e-05, 'yahoo': 6.265140756829004e-05, 'days': 0.00043855985297803026, '3g': 4.176760504552669e-05, 'perfect': 4.176760504552669e-05, 'after': 0.001211260546320274, 'password': 8.353521009105338e-05, 'd': 0.0013574471639796173, 'another': 0.0005638626681146103, 'credited': 4.176760504552669e-05, 'borin': 2.0883802522763345e-05, 'instantly': 2.0883802522763345e-05, 'unable': 4.176760504552669e-05, 'there': 0.0025895915128226546, 'hey': 0.001503633781638961, 'lookin': 8.353521009105338e-05, 'simply': 6.265140756829004e-05, 'pounds': 4.176760504552669e-05, 'from': 0.0021510316598446245, 'congrats': 0.00016707042018210676, 'did': 0.001691588004343831, 'see': 0.002004845042185281, 'just': 0.004406482332303066, 'message': 0.0008144682983877705, 'terms': 6.265140756829004e-05, 'box': 8.353521009105338e-05, 'pin': 6.265140756829004e-05, 'pick': 0.0010441901261381671, 'account': 0.0003341408403642135, 'mths': 2.0883802522763345e-05, 'lots': 0.0001879542227048701, 'bored': 0.0002923732353186868, 'faster': 4.176760504552669e-05, 'sub': 2.0883802522763345e-05, 'mp3': 4.176760504552669e-05, 's': 0.00020883802522763344, 'sort': 0.0001461866176593434, 'send': 0.001983961239662518, 'gay': 4.176760504552669e-05, 'people': 0.000668281680728427, 'so': 0.00580569710132821, 'unlimited': 8.353521009105338e-05, 'energy': 8.353521009105338e-05, 'takes': 0.0001879542227048701, '4u': 6.265140756829004e-05, 'mini': 4.176760504552669e-05, 'listen': 0.0001461866176593434, 'nos': 4.176760504552669e-05, 'enter': 6.265140756829004e-05, 'informed': 6.265140756829004e-05, 'free': 0.0007727006933422437, 'downloaded': 2.0883802522763345e-05, 'has': 0.001628936596775541, 'answer': 0.00020883802522763344, '2day': 6.265140756829004e-05, 'ya': 0.0007100492857739537, 'great': 0.0014409823740706709, '1000s': 2.0883802522763345e-05, 'str': 6.265140756829004e-05, 'number': 0.0008980035084788238, 'off': 0.0007309330882967171, 'held': 2.0883802522763345e-05, 'in': 0.011694929412747473, 'film': 0.00012530281513658008, 'miss': 0.0009815387185698771, 'meet': 0.0010441901261381671, 'secret': 8.353521009105338e-05, 'knows': 0.0001461866176593434, 'brought': 4.176760504552669e-05, 'unique': 2.0883802522763345e-05, 'kick': 8.353521009105338e-05, 'why': 0.0010024225210926406, 'nights': 2.0883802522763345e-05, 'suzy': 2.0883802522763345e-05, 'wkend': 2.0883802522763345e-05, 'txt': 0.00020883802522763344, 'being': 0.0004803274580235569, 'helen': 2.0883802522763345e-05, 'benefits': 2.0883802522763345e-05, 'started': 0.0003132570378414502, 'log': 0.00012530281513658008, 'city': 2.0883802522763345e-05, 'b4': 0.00010441901261381672, 'thinks': 6.265140756829004e-05, 'hi': 0.0016498203992983042, 'ones': 0.00012530281513658008, 'here': 0.0015454013866844874, 'have': 0.006390443571965583, 'how': 0.003821735861665692, 'in2': 4.176760504552669e-05, 'dates': 2.0883802522763345e-05, 'saturday': 0.0001461866176593434, 'only': 0.0018586584245259376, 'with': 0.0038635034667112186, 'pc': 4.176760504552669e-05, 'yours': 0.0001461866176593434, 'cd': 2.0883802522763345e-05, 'keep': 0.0010233063236154039, 'ok': 0.0037590844540974023, 'immediately': 6.265140756829004e-05, 'straight': 6.265140756829004e-05, 'still': 0.002109264054799098, 'luv': 0.0004594436555007936, 'suite': 2.0883802522763345e-05, 'center': 2.0883802522763345e-05, 'minutes': 0.00033414 ...

# %% [markdown]
# # Prediction Model
#
# ### Naive-Bayes Classification - Assumes every feature(word) is independent of each other.
#
# This means: The probability of a message being spam given its words equals the probability of seeing these words in spam messages, multiplied by the overall probability of spam, divided by the probability of seeing these words in any message.
#
# ```P(Spam|Words) = P(Words|Spam) * P(Spam) / P(Words)```
#
# The model would:
#
# ```Calculate P(Spam) = 0.13 (13% of all messages are spam)```
#
# Look up: ```P("urgent"|Spam) = 0.02 (2% of words in spam are "urgent")```
#
# And do the same for non-spam:
#
# ```P(Not Spam) = 0.87 (87% of messages aren't spam)```
#
# ```P("urgent"|Not Spam) = 0.001```
#
# Log Probabilities:
# Your code uses log probabilities for two reasons:
# ```spam_score = sum([np.log(p) for p in spam_probs]) + np.log(FRAC_SPAM_TEXTS)```

# %%
def predict_text(t, verbose=False):
    #if some word doesnt appear in either spam or non-spam BOW, disregard it
    valid_words = [w for w in t if w in train_spam_bow]

    #get the probabilities of each valid word showing up in spam and non-spam BOW
    spam_probs = [train_spam_bow[w] for w in valid_words]
    non_spam_probs = [train_non_spam_bow[w] for w in valid_words]

    #print probs if requested
    if verbose:
        data_df = pd.DataFrame()
        data_df['word'] = valid_words
        data_df['spam_prob'] = spam_probs
        data_df['non_spam_prob'] = non_spam_probs
        data_df['ratio'] = [s/n if n > 0 else np.inf for s,n in zip(spam_probs, non_spam_probs)]
        print(data_df)

    #calculate spam score as sum of logs for all probabilities
    spam_score = sum([np.log(p) for p in spam_probs]) + np.log(FRAC_SPAM_TEXTS)

    #calculate non-spam score as sum of logs for all probabilities
    non_spam_score = sum([np.log(p) for p in non_spam_probs]) + np.log(1-FRAC_SPAM_TEXTS)

    #if verbose, report the two scores
    if verbose:
        print('Spam Score: %s'%spam_score)
        print('Non-Spam Score: %s'%non_spam_score)

    #if spam score is higher, mark this as spam
    return (spam_score >= non_spam_score)

# %% [markdown]
# # Test on real text

# %%
predict_text('urgent call this number'.split(), verbose=True)
# Out:
#      word  spam_prob  non_spam_prob       ratio
# 0  urgent   0.003262       0.000021  156.204117
# 1    call   0.019262       0.003676    5.240614
# 2    this   0.004738       0.003467    1.366674
# 3  number   0.001864       0.000898    2.075802
# Spam Score: -23.283767355341944
# Non-Spam Score: -29.21240372953449
# np.True_

# %%
predict_text('hey do you want to go a movie tonight'.split(), verbose=True)
# Out:
#       word  spam_prob  non_spam_prob     ratio
# 0      hey   0.000311       0.001504  0.206619
# 1       do   0.001243       0.005221  0.238025
# 2      you   0.015767       0.026314  0.599196
# 3     want   0.001320       0.002548  0.518242
# 4       to   0.038602       0.022283  1.732348
# 5       go   0.001864       0.003404  0.547604
# 6        a   0.021437       0.014535  1.474834
# 7    movie   0.000155       0.000313  0.495886
# 8  tonight   0.000078       0.000773  0.100517
# Spam Score: -59.13351273279187
# Non-Spam Score: -50.46706981273259
# np.False_

# %%
predict_text('offer for unlimited money call now'.split(), verbose=True)
# Out:
#         word  spam_prob  non_spam_prob     ratio
# 0      offer   0.001010       0.000125  8.058149
# 1        for   0.011417       0.006954  1.641785
# 2  unlimited   0.000621       0.000084  7.438291
# 3      money   0.000233       0.000752  0.309929
# 4       call   0.019262       0.003676  5.240614
# 5        now   0.010563       0.003864  2.734075
# Spam Score: -37.59035945888617
# Non-Spam Score: -41.848593946464284
# np.True_

# %%
predict_text('are you at class yet'.split(), verbose=True)
# Out:
#     word  spam_prob  non_spam_prob     ratio
# 0    are   0.004117       0.005973  0.689212
# 1    you   0.015767       0.026314  0.599196
# 2     at   0.001320       0.005555  0.237690
# 3  class   0.000155       0.000606  0.256493
# 4    yet   0.000078       0.000731  0.106261
# Spam Score: -36.476977722633414
# Non-Spam Score: -28.731613315971043
# np.False_

# %%
predictions = test_spam_df.text.apply(lambda t: predict_text(t.split()))

# %%
frac_spam_messages_correctly_detected = np.sum((predictions == True) & (test_spam_df.spam == True)) / np.sum(test_spam_df.spam == True)
print('Fraction Spam Correctly Detected: %s'%frac_spam_messages_correctly_detected)
# Out:
# Fraction Spam Correctly Detected: 0.9117647058823529

# %%
frac_valid_sent_to_spam = np.sum((predictions == True) & (test_spam_df.spam == False)) / np.sum(test_spam_df.spam == False)
print('Fraction Valid Messages Sent to Spam: %s'%frac_valid_sent_to_spam)
# Out:
# Fraction Valid Messages Sent to Spam: 0.0170299727520436
